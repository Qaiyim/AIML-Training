# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data= { 
    'Hours':[1,2,3,4,5,6,7,8],
    'Marks':[25,35,45,50,55,65,70,80]
}
df=pd.DataFrame(data)

# %%
# Step 3: Define Features and Target
X = df[['Hours']]
y = df['Marks']

# %%
# Step 4: Split Data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.8, random_state=0)
print('Training samples:', len(X_train))
print('Testing samples:', len(X_test))
# Out:
# Training samples: 1
# Testing samples: 7

# %%
# Create the model and Train the model
model = LinearRegression()
model.fit(X_train,y_train)
print('Model Trained Successfully!')
# Out:
# Model Trained Successfully!

# %%
y_pred=model.predict(X_test)
print(y_test.values)
print(X_test)
print('Actual:',list(y_test.values))
print('Predicted:', list(y_pred))
# Out:
# [70 45 35 80 50 25 65]
#    Hours
# 6      7
# 2      3
# 1      2
# 7      8
# 3      4
# 0      1
# 5      6
# Actual: [np.int64(70), np.int64(45), np.int64(35), np.int64(80), np.int64(50), np.int64(25), np.int64(65)]
# Predicted: [np.float64(55.0), np.float64(55.0), np.float64(55.0), np.float64(55.0), np.float64(55.0), np.float64(55.0), np.float64(55.0)]
